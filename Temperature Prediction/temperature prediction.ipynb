# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/barc-intern-1/OdettedataML1.csv
# /kaggle/input/barc-intern-1/japan2.csv
# /kaggle/input/barc-intern-1/final data.csv

# %%
# !pip install pycaret -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 1.4 MB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 10.4 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 81.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 19.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 68.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 55.4 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.6/200.6 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 72.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 41.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 48.6 MB/s eta 0:00:0000:0100:01m
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.1/130.1 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.6 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 12.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.11.4 which is incompatible.
# datasets 3.5.0 requires fsspec[http]<=2024.12.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# nilearn 0.11.1 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.9.1 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.5, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# pandas-gbq 0.26.1 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# bigframes 1.36.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# ibis-framework 9.2.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# ibis-framework 9.2.0 requires toolz<1,>=0.11, but you have toolz 1.0.0 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# mizani 0.13.1 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.

# %%
import numpy as np
import pandas as pd
from pycaret.regression import *
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use(['seaborn'])
from sklearn import set_config
set_config(display='text')
import optuna
import catboost as cb
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np
from datetime import datetime

# %%
df3 = pd.read_csv("/kaggle/input/barc-intern-1/final data.csv")

# Drop the target column to prepare for normalization
df4 = df3.drop('DeltaT', axis=1)

# %%
# Normalize the features
df_norm2 = (df4 - df4.min()) / (df4.max() - df4.min())
df_norm2 = pd.concat((df_norm2, df3.DeltaT), axis=1)

# %%
# Display the correlation matrix
correlation_matrix = df3.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Features')
plt.savefig('correlation_matrix.png')

# %%
# Set up PyCaret with cross-validation
# Using 5-fold cross-validation to ensure robust model evaluation
reg_setup = setup(data=df_norm2, target='DeltaT', session_id=123, 
                 normalize=False,  # Already normalized
                 train_size=0.8,
                 fold=5,  # 5-fold cross-validation
                 verbose=False)

# %%
best_model = compare_models(sort='R2', n_select=1, verbose=True)
# Out:
# <style type="text/css">
# #T_a997c th {
#   text-align: left;
# }
# #T_a997c_row0_col0, #T_a997c_row0_col1, #T_a997c_row0_col6, #T_a997c_row1_col0, #T_a997c_row1_col1, #T_a997c_row1_col2, #T_a997c_row1_col3, #T_a997c_row1_col4, #T_a997c_row1_col5, #T_a997c_row1_col6, #T_a997c_row2_col0, #T_a997c_row2_col2, #T_a997c_row2_col3, #T_a997c_row2_col4, #T_a997c_row2_col5, #T_a997c_row3_col0, #T_a997c_row3_col1, #T_a997c_row3_col2, #T_a997c_row3_col3, #T_a997c_row3_col4, #T_a997c_row3_col5, #T_a997c_row3_col6, #T_a997c_row4_col0, #T_a997c_row4_col1, #T_a997c_row4_col2, #T_a997c_row4_col3, #T_a997c_row4_col4, #T_a997c_row4_col5, #T_a997c_row4_col6, #T_a997c_row5_col0, #T_a997c_row5_col1, #T_a997c_row5_col2, #T_a997c_row5_col3, #T_a997c_row5_col4, #T_a997c_row5_col5, #T_a997c_row5_col6, #T_a997c_row6_col0, #T_a997c_row6_col1, #T_a997c_row6_col2, #T_a997c_row6_col3, #T_a997c_row6_col4, #T_a997c_row6_col5, #T_a997c_row6_col6, #T_a997c_row7_col0, #T_a997c_row7_col1, #T_a997c_row7_col2, #T_a997c_row7_col3, #T_a997c_row7_col4, #T_a997c_row7_col5, #T_a997c_row7_col6, #T_a997c_row8_col0, #T_a997c_row8_col1, #T_a997c_row8_col2, #T_a997c_row8_col3, #T_a997c_row8_col4, #T_a997c_row8_col5, #T_a997c_row8_col6, #T_a997c_row9_col0, #T_a997c_row9_col1, #T_a997c_row9_col2, #T_a997c_row9_col3, #T_a997c_row9_col4, #T_a997c_row9_col5, #T_a997c_row9_col6, #T_a997c_row10_col0, #T_a997c_row10_col1, #T_a997c_row10_col2, #T_a997c_row10_col3, #T_a997c_row10_col4, #T_a997c_row10_col5, #T_a997c_row10_col6, #T_a997c_row11_col0, #T_a997c_row11_col1, #T_a997c_row11_col2, #T_a997c_row11_col3, #T_a997c_row11_col4, #T_a997c_row11_col5, #T_a997c_row11_col6, #T_a997c_row12_col0, #T_a997c_row12_col1, #T_a997c_row12_col2, #T_a997c_row12_col3, #T_a997c_row12_col4, #T_a997c_row12_col5, #T_a997c_row12_col6, #T_a997c_row13_col0, #T_a997c_row13_col1, #T_a997c_row13_col2, #T_a997c_row13_col3, #T_a997c_row13_col4, #T_a997c_row13_col5, #T_a997c_row13_col6, #T_a997c_row14_col0, #T_a997c_row14_col1, #T_a997c_row14_col2, #T_a997c_row14_col3, #T_a997c_row14_col4, #T_a997c_row14_col5, #T_a997c_row14_col6, #T_a997c_row15_col0, #T_a997c_row15_col1, #T_a997c_row15_col2, #T_a997c_row15_col3, #T_a997c_row15_col4, #T_a997c_row15_col5, #T_a997c_row15_col6, #T_a997c_row16_col0, #T_a997c_row16_col1, #T_a997c_row16_col2, #T_a997c_row16_col3, #T_a997c_row16_col4, #T_a997c_row16_col5, #T_a997c_row16_col6, #T_a997c_row17_col0, #T_a997c_row17_col1, #T_a997c_row17_col2, #T_a997c_row17_col3, #T_a997c_row17_col4, #T_a997c_row17_col5, #T_a997c_row17_col6, #T_a997c_row18_col0, #T_a997c_row18_col1, #T_a997c_row18_col2, #T_a997c_row18_col3, #T_a997c_row18_col4, #T_a997c_row18_col5, #T_a997c_row18_col6, #T_a997c_row19_col0, #T_a997c_row19_col1, #T_a997c_row19_col2, #T_a997c_row19_col3, #T_a997c_row19_col4, #T_a997c_row19_col5, #T_a997c_row19_col6 {
#   text-align: left;
# }
# #T_a997c_row0_col2, #T_a997c_row0_col3, #T_a997c_row0_col4, #T_a997c_row0_col5, #T_a997c_row2_col1, #T_a997c_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a997c_row0_col7, #T_a997c_row1_col7, #T_a997c_row2_col7, #T_a997c_row3_col7, #T_a997c_row4_col7, #T_a997c_row5_col7, #T_a997c_row6_col7, #T_a997c_row8_col7, #T_a997c_row11_col7, #T_a997c_row12_col7, #T_a997c_row14_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a997c_row7_col7, #T_a997c_row9_col7, #T_a997c_row10_col7, #T_a997c_row13_col7, #T_a997c_row15_col7, #T_a997c_row16_col7, #T_a997c_row17_col7, #T_a997c_row18_col7, #T_a997c_row19_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a997c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a997c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a997c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a997c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a997c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a997c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a997c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a997c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a997c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a997c_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_a997c_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_a997c_row0_col1" class="data row0 col1" >6.6003</td>
#       <td id="T_a997c_row0_col2" class="data row0 col2" >88.5477</td>
#       <td id="T_a997c_row0_col3" class="data row0 col3" >9.3381</td>
#       <td id="T_a997c_row0_col4" class="data row0 col4" >0.8707</td>
#       <td id="T_a997c_row0_col5" class="data row0 col5" >0.4539</td>
#       <td id="T_a997c_row0_col6" class="data row0 col6" >0.4113</td>
#       <td id="T_a997c_row0_col7" class="data row0 col7" >0.4220</td>
#     </tr>
#     <tr>
#       <th id="T_a997c_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_a997c_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_a997c_row1_col1" class="data row1 col1" >7.4613</td>
#       <td id="T_a997c_row1_col2" class="data row1 col2" >102.1118</td>
#       <td id="T_a997c_row1_col3" class="data row1 col3" >10.0543</td>
#       <td id="T_a997c_row1_col4" class="data row1 col4" >0.8522</td>
#       <td id="T_a997c_row1_col5" class="data row1 col5" >0.4753</td>
#       <td id="T_a997c_row1_col6" class="data row1 col6" >0.4409</td>
#       <td id="T_a997c_row1_col7" class="data row1 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_a997c_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_a997c_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_a997c_row2_col1" class="data row2 col1" >6.5338</td>
#       <td id="T_a997c_row2_col2" class="data row2 col2" >102.1861</td>
#       <td id="T_a997c_row2_col3" class="data row2 col3" >9.9975</td>
#       <td id="T_a997c_row2_col4" class="data row2 col4" >0.8505</td>
#       <td id="T_a997c_row2_col5" class="data row2 col5" >0.4641</td>
#       <td id="T_a997c_row2_col6" class="data row2 col6" >0.3993</td>
#       <td id="T_a997c_row2_col7" class="data row2 col7" >0.0720</td>
#     </tr>
#     <tr>
#       <th id="T_a997c_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_a997c_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_a997c_row3_col1" class="data row3 col1" >7.7610</td>
#       <td id="T_a997c_row3_col2" class="data row3 col2" >114.7786</td>
#       <td id="T_a997c_row3_col3" class="data row3 col3" >10.6077</td>
#       <td id="T_a997c_row3_col4" class="data row3 col4" >0.8334</td>
#       <td id="T_a997c_row3_col5" class="data row3 col5" >0.4836</td>
#       <td id="T_a997c_row3_col6" class="data row3 col6" >0.4562</td>
#       <td id="T_a997c_row3_col7" class="data row3 col7" >0.1020</td>
#     </tr>
#     <tr>
#       <th id="T_a997c_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_a997c_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_a997c_row4_col1" class="data row4 col1" >6.9468</td>
#       <td id="T_a997c_row4_col2" class="data row4 col2" >117.2842</td>
#       <td id="T_a997c_row4_col3" class="data row4 col3" >10.6930</td>
#       <td id="T_a997c_row4_col4" class="data row4 col4" >0.8292</td>
#       <td id="T_a997c_row4_col5" class="data row4 col5" >0.4890</td>
#       <td id="T_a997c_row4_col6" class="data row4 col6" >0.4062</td>
#       <td id="T_a997c_row4_col7" class="data row4 col7" >0.0540</td>
#     </tr>
#     <tr>
#       <th id="T_a997c_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_a997c_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_a997c_row5_col1" class="data row5 col1" >9.4621</td>
#       <td id="T_a997c_row5_col2" class="data row5 col2" >138.6055</td>
#       <td id="T_a997c_row5_col3" class="data row5

# %%
# Tune the best model to improve R2 score
tuned_model = tune_model(best_model, 
                        optimize='R2', 
                        n_iter=50,  # Increase iterations for better tuning
                        verbose=True)
# Out:
# <style type="text/css">
# #T_c54cc_row5_col0, #T_c54cc_row5_col1, #T_c54cc_row5_col2, #T_c54cc_row5_col3, #T_c54cc_row5_col4, #T_c54cc_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c54cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c54cc_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c54cc_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c54cc_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c54cc_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c54cc_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c54cc_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c54cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c54cc_row0_col0" class="data row0 col0" >7.0846</td>
#       <td id="T_c54cc_row0_col1" class="data row0 col1" >87.6591</td>
#       <td id="T_c54cc_row0_col2" class="data row0 col2" >9.3626</td>
#       <td id="T_c54cc_row0_col3" class="data row0 col3" >0.8950</td>
#       <td id="T_c54cc_row0_col4" class="data row0 col4" >0.3905</td>
#       <td id="T_c54cc_row0_col5" class="data row0 col5" >0.4015</td>
#     </tr>
#     <tr>
#       <th id="T_c54cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c54cc_row1_col0" class="data row1 col0" >5.7590</td>
#       <td id="T_c54cc_row1_col1" class="data row1 col1" >90.3195</td>
#       <td id="T_c54cc_row1_col2" class="data row1 col2" >9.5037</td>
#       <td id="T_c54cc_row1_col3" class="data row1 col3" >0.8820</td>
#       <td id="T_c54cc_row1_col4" class="data row1 col4" >0.4588</td>
#       <td id="T_c54cc_row1_col5" class="data row1 col5" >0.6090</td>
#     </tr>
#     <tr>
#       <th id="T_c54cc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c54cc_row2_col0" class="data row2 col0" >4.7697</td>
#       <td id="T_c54cc_row2_col1" class="data row2 col1" >48.0254</td>
#       <td id="T_c54cc_row2_col2" class="data row2 col2" >6.9300</td>
#       <td id="T_c54cc_row2_col3" class="data row2 col3" >0.9354</td>
#       <td id="T_c54cc_row2_col4" class="data row2 col4" >0.4517</td>
#       <td id="T_c54cc_row2_col5" class="data row2 col5" >0.1977</td>
#     </tr>
#     <tr>
#       <th id="T_c54cc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c54cc_row3_col0" class="data row3 col0" >5.7764</td>
#       <td id="T_c54cc_row3_col1" class="data row3 col1" >80.4363</td>
#       <td id="T_c54cc_row3_col2" class="data row3 col2" >8.9686</td>
#       <td id="T_c54cc_row3_col3" class="data row3 col3" >0.8619</td>
#       <td id="T_c54cc_row3_col4" class="data row3 col4" >0.6005</td>
#       <td id="T_c54cc_row3_col5" class="data row3 col5" >0.4092</td>
#     </tr>
#     <tr>
#       <th id="T_c54cc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c54cc_row4_col0" class="data row4 col0" >7.5112</td>
#       <td id="T_c54cc_row4_col1" class="data row4 col1" >131.8362</td>
#       <td id="T_c54cc_row4_col2" class="data row4 col2" >11.4820</td>
#       <td id="T_c54cc_row4_col3" class="data row4 col3" >0.7886</td>
#       <td id="T_c54cc_row4_col4" class="data row4 col4" >0.3162</td>
#       <td id="T_c54cc_row4_col5" class="data row4 col5" >0.3202</td>
#     </tr>
#     <tr>
#       <th id="T_c54cc_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_c54cc_row5_col0" class="data row5 col0" >6.1802</td>
#       <td id="T_c54cc_row5_col1" class="data row5 col1" >87.6553</td>
#       <td id="T_c54cc_row5_col2" class="data row5 col2" >9.2494</td>
#       <td id="T_c54cc_row5_col3" class="data row5 col3" >0.8726</td>
#       <td id="T_c54cc_row5_col4" class="data row5 col4" >0.4435</td>
#       <td id="T_c54cc_row5_col5" class="data row5 col5" >0.3875</td>
#     </tr>
#     <tr>
#       <th id="T_c54cc_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_c54cc_row6_col0" class="data row6 col0" >0.9919</td>
#       <td id="T_c54cc_row6_col1" class="data row6 col1" >26.7645</td>
#       <td id="T_c54cc_row6_col2" class="data row6 col2" >1.4505</td>
#       <td id="T_c54cc_row6_col3" class="data row6 col3" >0.0484</td>
#       <td id="T_c54cc_row6_col4" class="data row6 col4" >0.0938</td>
#       <td id="T_c54cc_row6_col5" class="data row6 col5" >0.1344</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 50 candidates, totalling 250 fits

# %%
# Finalize the tuned model
final_model = finalize_model(tuned_model)

# Make predictions on the hold-out test set
predictions = predict_model(final_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d7fa8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7fa8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d7fa8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d7fa8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d7fa8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d7fa8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d7fa8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d7fa8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7fa8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7fa8_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_d7fa8_row0_col1" class="data row0 col1" >0.8705</td>
#       <td id="T_d7fa8_row0_col2" class="data row0 col2" >1.8939</td>
#       <td id="T_d7fa8_row0_col3" class="data row0 col3" >1.3762</td>
#       <td id="T_d7fa8_row0_col4" class="data row0 col4" >0.9981</td>
#       <td id="T_d7fa8_row0_col5" class="data row0 col5" >0.1634</td>
#       <td id="T_d7fa8_row0_col6" class="data row0 col6" >0.0647</td>
#     </tr>
#   </tbody>
# </table>

# %%
X = df_norm2.drop('DeltaT', axis=1)
y = df_norm2['DeltaT']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=123)

# %%
y_train_pred = final_model.predict(X_train)
y_test_pred = final_model.predict(X_test)

# %%
train_r2_score = r2_score(y_train, y_train_pred)
test_r2_score = r2_score(y_test, y_test_pred)
# Out:
# Train R2 Score: 0.9964
# Test R2 Score: 0.9981

# %%
plt.rcParams.update({
    'font.size': 12,
    'font.family': 'Times New Roman',
    'axes.labelsize': 14,
    'axes.titlesize': 16,
    'legend.fontsize': 12,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'figure.dpi': 300,
    'savefig.dpi': 300,
    'axes.spines.top': False,
    'axes.spines.right': False,
})



fig, ax = plt.subplots(figsize=(10, 10))  # Match the size from the example
ax.scatter(y_train, y_train_pred, s=400, marker='s', linewidth=2, edgecolors="blue", 
           color="lavender", label=f'Train data (R² = {train_r2_score:.3f})')
ax.scatter(y_test, y_test_pred, s=500, marker='s', linewidth=2, edgecolors="white", 
           color="red", label=f'Test data (R² = {test_r2_score:.3f})')
min_val = min(y.min(), min(y_train_pred.min(), y_test_pred.min()))
max_val = max(y.max(), max(y_train_pred.max(), y_test_pred.max()))
xl = yl = [min_val, max_val]
ax.plot(xl, yl, linestyle='dashed', color='black', linewidth=3.5, label='Ideal Fit (y=x)')
# Customize labels, legend, and ticks
ax.set_xlabel('Actual ΔT (°C)', fontsize=45)
ax.set_ylabel('Predicted ΔT (°C)', fontsize=45)
ax.set_title('Actual vs Predicted ΔT', fontsize=16, pad=15)
ax.legend(loc='upper left', fontsize='xx-large', facecolor='w', edgecolor='black')
ax.tick_params(axis='both', which='major', labelsize=30)
ax.grid(True, linestyle='--', alpha=0.7)
ax.set_aspect('equal', adjustable='box')
plt.tight_layout()

# %%
plot_model(final_model)

# %%
if hasattr(final_model, 'feature_importances_'):
    feature_importance = final_model.feature_importances_
    feature_names = df_norm2.drop('DeltaT', axis=1).columns
    importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
    importance_df = importance_df.sort_values(by='Importance', ascending=False)
    
    fig, ax = plt.subplots(figsize=(8, 6))
    sns.barplot(x='Importance', y='Feature', data=importance_df, palette='Blues_r', ax=ax)
    ax.set_xlabel('Feature Importance', fontsize=14, labelpad=10)
    ax.set_ylabel('Feature', fontsize=14, labelpad=10)
    ax.set_title('Feature Importance for ΔT Prediction', fontsize=16, pad=15)
    ax.tick_params(axis='both', which='major', direction='in', length=5)
    for i, v in enumerate(importance_df['Importance']):
        ax.text(v, i, f'{v:.2f}', va='center', ha='left', fontsize=10, color='black', x=v + 0.02)
    plt.tight_layout()
    plt.savefig('feature_importance_professional.png', bbox_inches='tight', dpi=300)
else:
    print("Feature importance not available for this model.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/881755273.py in <cell line: 0>()
#      12     ax.tick_params(axis='both', which='major', direction='in', length=5)
#      13     for i, v in enumerate(importance_df['Importance']):
# ---> 14         ax.text(v, i, f'{v:.2f}', va='center', ha='left', fontsize=10, color='black', x=v + 0.02)
#      15     plt.tight_layout()
#      16     plt.savefig('feature_importance_professional.png', bbox_inches='tight', dpi=300)
#
# TypeError: Axes.text() got multiple values for argument 'x'

# %%
# !pip install shap -q

# %%
import shap
pd.set_option('display.max_columns', None)
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
interpret_model(best_model, plot = 'summary')
